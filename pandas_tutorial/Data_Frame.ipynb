# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
my_data = randn(4, 3)  # Rows, Columns
my_rows = ["A", "B", "C", "D"]
my_columns = ["Monday", "Tuesday", "Friday"]

# %%
# Create Dataframe
my_df = pd.DataFrame(my_data, my_rows, my_columns)
my_df
# Out:
#      Monday   Tuesday    Friday
# A  0.849677 -0.073574  0.066278
# B  0.688841 -0.507989 -1.216128
# C  0.332758  1.491823  0.581583
# D -1.405208  0.691781  0.850368

# %%
# import csv file
my_df2 = pd.read_csv(".\output-onlinetools.txt")
my_df2
# Out:
#       consonant      topic         wind          belt    applied         mail  \
# 0        caught      began     contrast     perfectly    account         date
# 1          base      shape       double         front     phrase    newspaper
# 2         serve       flag         well         about       care         them
# 3     scientist      speak      between        number     spider        equal
# 4   grandmother       walk      package       product       time        speak
# 5         chain  determine      process       climate    realize        first
# 6        indeed       mark       speech         angry  condition        uncle
# 7         shine    stopped         goes         brown    clothes         inch
# 8          felt      lucky     yourself        sister       warm      running
# 9      pleasure       word        ruler       carried       book        happy
# 10      replace       cent        aside        monkey     became   surrounded
# 11         fell   sunlight       silver         truck   handsome         jack
# 12       muscle      small          may     knowledge       join     personal
# 13       volume   slightly      applied         owner     should       fierce
# 14    continent       jump         nine  neighborhood    heading  appropriate
# 15           so     liquid         meat       element      ruler       public
# 16         real       hang     physical        jungle   thousand       fourth
# 17      outside  beautiful        press        circus     rubber          sky
# 18        round      guide      feature           how  continued     favorite
# 19       battle      slabs          bee        parent     fought        learn
# 20         rest        eye        quick       gravity        low      combine
# 21       police    somehow  environment      audience   gasoline         when
# 22           do      spell     daughter         quick      pound     possibly
# 23         cage    climate        press           fox       nuts   expression
# 24        color      table        forty       heading       crew      limited
# 25       length      knife        would         order       pond     evidence
# 26       throat        box         easy    mysterious       gate         poor
# 27      example     second       yellow     equipment   movement         song
# 28        union      occur         meat          lead  whispered          few
# 29          day       with      serious        nature     spirit         like
#
#           guide       depth   daughter      charge
# 0         rhyme  experiment  different     factory
# 1     direction         let      sheep     stopped
# 2        itself       alive   discover     section
# 3      invented   disappear       grew      future
# 4         drawn        tube    central       thing
# 5         avoid     beneath      blood    whatever
# 6        forget   education      spend       ready
# 7        nearby        love     pocket    compound
# 8        eleven      golden  perfectly        test
# 9         money       heard      chest       laugh
# 10        short      nearby   stranger         bet
# 11    structure    parallel     advice    identity
# 12          tin       early        ice       grain
# 13         sent        lake        cut         box
# 14       phrase       lying     column        dawn
# 15      excited   something      price       learn
# 16         stay      number        log        left
# 17         glad      giving       fill       bound
# 18       garden         bat      green    position
# 19       mirror        send  president         bet
# 20      thought       rhyme       team        come
# 21        place        some     pretty  protection
# 22  independent      mother    unusual        roll
# 23    condition        mass        saw  surrounded
# 24         held   substance      bound         saw
# 25      central   perfectly    shaking     develop
# 26       hollow        roof       foot      yellow
# 27      cutting      mental      known        cast
# 28         very       eight       drop        tube
# 29        drove        into       soap        calm

# %%
# Pull out rows
my_df2.loc[0]
# Out:
# consonant        caught
# topic             began
# wind           contrast
# belt          perfectly
# applied         account
# mail               date
# guide             rhyme
# depth        experiment
# daughter      different
# charge          factory
# Name: 0, dtype: object

# %%
# Pull out multiple rows
my_df2.loc[[0, 1]]
# Out:
#   consonant  topic      wind       belt  applied       mail      guide  \
# 0    caught  began  contrast  perfectly  account       date      rhyme
# 1      base  shape    double      front   phrase  newspaper  direction
#
#         depth   daughter   charge
# 0  experiment  different  factory
# 1         let      sheep  stopped
