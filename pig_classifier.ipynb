# %% [markdown]
# <a href="https://colab.research.google.com/github/olumidedaramola21/ml/blob/main/pig_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastai duckduckgo_search

# %%
from fastcore.all import *
from fastai.vision.all import *
from duckduckgo_search import DDGS
from fastdownload import download_url

def search_images(term, max_images=30):
  print(f"Searching for '{term}'")
  return L(DDGS().images(keywords=term, max_results=max_images)).itemgot('image')

download_url(search_images('pig photos', max_images=1)[0], 'pig.jpg', show_progress=False)
Image.open('pig.jpg').to_thumb(256, 256)
# Out:
# Searching for 'pig photos'
# <PIL.Image.Image image mode=RGB size=256x171>
